# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from sklearn.datasets import make_blobs

style.use('seaborn-talk')

krfont = {'family':'NaumGothic', 'weight':'bold','size':10}
matplotlib.rc('font',**krfont)
matplotlib.rcParams['axes.unicode_minus'] = False

X, y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std=0.5, shuffle=True, random_state = 0)

plt.scatter(X[:, 0], X[:,1], c='lightgray', marker='o',s=50)
plt.grid(True)
plt.show()

# %%
data = pd.read_csv("./bunt_sample_all_team_2019.csv")
data
# Out:
#     Unnamed: 0   이름      연도    팀    나이    P      G     타석     타수    득점  ...  \
# 0          0.0  박해민  2019.0   삼성  29.0   CF  144.0  581.0  506.0  64.0  ...
# 1          1.0  박해민  2019.0   삼성  29.0   CF  144.0  581.0  506.0  64.0  ...
# 2          2.0  박해민  2019.0   삼성  29.0   CF  144.0  581.0  506.0  64.0  ...
# 3          3.0  박해민  2019.0   삼성  29.0   CF  144.0  581.0  506.0  64.0  ...
# 4          4.0  박해민  2019.0   삼성  29.0   CF  144.0  581.0  506.0  64.0  ...
# ..         ...  ...     ...  ...   ...  ...    ...    ...    ...   ...  ...
# 72         2.0  장성우  2019.0   KT  29.0    C  127.0  413.0  366.0  25.0  ...
# 73         3.0  장성우  2019.0   KT  29.0    C  127.0  413.0  366.0  25.0  ...
# 74         0.0  박경수  2019.0   KT  35.0   2B  137.0  490.0  421.0  43.0  ...
# 75         1.0  박경수  2019.0   KT  35.0   2B  137.0  490.0  421.0  43.0  ...
# 76         NaN  NaN     NaN  NaN   NaN  NaN    NaN    NaN    NaN   NaN  ...
#
#     wRC+  WAR*  BABIP   RE24   WPA   타순   이닝     상황   스코어       wpa
# 0   77.0  1.28  0.275 -14.98 -1.36  2.0  3.0  무사 1루  0:00 -0.019000
# 1   77.0  1.28  0.275 -14.98 -1.36  1.0  5.0  무사 1루  1:01 -0.022000
# 2   77.0  1.28  0.275 -14.98 -1.36  1.0  8.0  무사 1루  1:01 -0.019000
# 3   77.0  1.28  0.275 -14.98 -1.36  1.0  7.0  무사 1루  2:03 -0.011000
# 4   77.0  1.28  0.275 -14.98 -1.36  1.0  9.0  무사 1루  2:01 -0.008000
# ..   ...   ...    ...    ...   ...  ...  ...    ...   ...       ...
# 72  82.7  1.28  0.319 -18.46 -1.94  8.0  7.0  무사 1루  2:01 -0.015000
# 73  82.7  1.28  0.319 -18.46 -1.94  8.0  5.0  무사 1루  1:00 -0.016000
# 74  97.3  2.16  0.298  -7.22  0.17  1.0  6.0  무사 1루  3:05 -0.008000
# 75  97.3  2.16  0.298  -7.22  0.17  6.0  7.0  무사 1루  1:01 -0.020000
# 76   NaN   NaN    NaN    NaN   NaN  NaN  NaN    NaN   NaN -0.016026
#
# [77 rows x 40 columns]

# %%
data_sample = data.loc[:,['wpa','타율','장타','WAR*']]
data_sample
# Out:
#          wpa     타율     장타  WAR*
# 0  -0.019000  0.239  0.328  1.28
# 1  -0.022000  0.239  0.328  1.28
# 2  -0.019000  0.239  0.328  1.28
# 3  -0.011000  0.239  0.328  1.28
# 4  -0.008000  0.239  0.328  1.28
# ..       ...    ...    ...   ...
# 72 -0.015000  0.262  0.339  1.28
# 73 -0.016000  0.262  0.339  1.28
# 74 -0.008000  0.247  0.375  2.16
# 75 -0.020000  0.247  0.375  2.16
# 76 -0.016026    NaN    NaN   NaN
#
# [77 rows x 4 columns]
